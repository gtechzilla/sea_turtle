# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#       Rescue_ID Date_TimeCaught     Researcher    CaptureSite ForagingGround  \
# 0  2000_RE_0060      2000-12-22  Researcher_25  CaptureSite_0          Ocean
# 1  2001_RE_0187      2001-10-28   Researcher_6  CaptureSite_0          Ocean
# 2  2001_RE_0197      2001-11-01   Researcher_6  CaptureSite_0          Ocean
# 3  2002_RE_0031      2002-03-11  Researcher_32  CaptureSite_0          Ocean
# 4  2002_RE_0118      2002-08-08  Researcher_25  CaptureSite_0          Ocean
#
#   CaptureMethod       Fisher                        LandingSite    Species  \
# 0           Net  Fisher_1072  LandingSite_CaptureSiteCategory_2  Species_6
# 1           Net   Fisher_520  LandingSite_CaptureSiteCategory_2  Species_6
# 2           Net  Fisher_1669  LandingSite_CaptureSiteCategory_2  Species_5
# 3           Net  Fisher_1798  LandingSite_CaptureSiteCategory_2  Species_6
# 4       Beached  Fisher_1918  LandingSite_CaptureSiteCategory_2  Species_5
#
# ...

# %%
#checking for unique values in our dataset
#we notice we have some discrepancy in the following columns
"""Sex-should only be 2 unique values but we have 4
Foraging ground should have 2 categories instead of 3
"""
data.nunique()
# Out:
# Rescue_ID                18062
# Date_TimeCaught           5237
# Researcher                  35
# CaptureSite                 29
# ForagingGround               3
# CaptureMethod               15
# Fisher                    2085
# LandingSite                  5
# Species                      8
# Tag_1                     8236
# Tag_2                      247
# Lost_Tags                  167
# T_Number                    38
# CCL_cm                    1338
# CCW_cm                    1262
# Weight_Kg                 1937
# Sex                          4
# TurtleCharacteristics    16343
# Status                     439
# ReleaseSite                271
# Date_TimeRelease          3008
# dtype: int64

# %%
#convert all in the Foraging ground to lowercase thus we have to sites
data['ForagingGround']=data['ForagingGround'].str.lower()

# %%
#checking for missing data per column
#both lost tags and T_number have significan missing data,thus we drop them
#data.drop(['Lost_Tags','T_Number'],axis=1,inplace=True)
data.isnull().sum()
# Out:
# Rescue_ID                   0
# Date_TimeCaught             0
# Researcher                  0
# CaptureSite                 0
# ForagingGround              0
# CaptureMethod               0
# Fisher                      0
# LandingSite                 0
# Species                     0
# Tag_1                       0
# Tag_2                       0
# CCL_cm                     24
# CCW_cm                     27
# Weight_Kg                5409
# Sex                      4330
# TurtleCharacteristics      41
# Status                   3633
# ReleaseSite                75
# Date_TimeRelease         6108
# dtype: int64

# %%
data['Sex'].str.count('Unknown').sum()
# Out:
# 13578.0
